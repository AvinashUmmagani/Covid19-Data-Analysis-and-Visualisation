# %%
# Importing Modules
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Importing Covid 19 Dataset**

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-afc81933-30b0-49ad-b018-fe171602b47a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-afc81933-30b0-49ad-b018-fe171602b47a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving worldwide_happiness_report.csv to worldwide_happiness_report (1).csv
# Saving covid19_Confirmed_dataset.csv to covid19_Confirmed_dataset (1).csv

# %%
import io
corona_dataset_csv = pd.read_csv(io.BytesIO(data_to_load['covid19_Confirmed_dataset.csv']))
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  ...  7/29/20  7/30/20
# 0                           NaN          Afghanistan  ...    36471    36542
# 1                           NaN              Albania  ...     5105     5197
# 2                           NaN              Algeria  ...    29229    29831
# 3                           NaN              Andorra  ...      918      922
# 4                           NaN               Angola  ...     1078     1109
# 5                           NaN  Antigua and Barbuda  ...       91       91
# 6                           NaN            Argentina  ...   178996   185373
# 7                           NaN              Armenia  ...    37937    38196
# 8  Australian Capital Territory            Australia  ...      113      113
# 9               New South Wales            Australia  ...     3736     3756
#
# [10 rows x 195 columns]

# %%
corona_dataset_csv.shape
# Out:
# (266, 195)

# %% [markdown]
# **Deleting Useless Columns**

# %%
corona_dataset_csv.drop(['Lat','Long'], axis = 1,inplace=True)
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  ...  7/29/20  7/30/20
# 0                           NaN          Afghanistan  ...    36471    36542
# 1                           NaN              Albania  ...     5105     5197
# 2                           NaN              Algeria  ...    29229    29831
# 3                           NaN              Andorra  ...      918      922
# 4                           NaN               Angola  ...     1078     1109
# 5                           NaN  Antigua and Barbuda  ...       91       91
# 6                           NaN            Argentina  ...   178996   185373
# 7                           NaN              Armenia  ...    37937    38196
# 8  Australian Capital Territory            Australia  ...      113      113
# 9               New South Wales            Australia  ...     3736     3756
#
# [10 rows x 193 columns]

# %% [markdown]
# **Aggregating by Country/Region**

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  ...  7/28/20  7/29/20  7/30/20
# Country/Region                                  ...
# Afghanistan                0        0        0  ...    36368    36471    36542
# Albania                    0        0        0  ...     4997     5105     5197
# Algeria                    0        0        0  ...    28615    29229    29831
# Andorra                    0        0        0  ...      907      918      922
# Angola                     0        0        0  ...     1000     1078     1109
# Antigua and Barbuda        0        0        0  ...       86       91       91
# Argentina                  0        0        0  ...   173355   178996   185373
# Armenia                    0        0        0  ...    37629    37937    38196
# Australia                  0        0        0  ...    15582    16298    16903
# Austria                    0        0        0  ...    20677    20850    20955
#
# [10 rows x 191 columns]

# %% [markdown]
# **Visualising Data related to country**

# %%
corona_dataset_aggregated.loc['India'].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['US'].plot()
plt.legend()

# %% [markdown]
# **Calculating Maximum Infection Rate**

# %%
corona_dataset_aggregated.loc['India'].diff().plot()

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max infection rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  7/29/20  7/30/20  max infection rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...    36471    36542               915.0
# Albania               0        0        0  ...     5105     5197               126.0
# Algeria               0        0        0  ...    29229    29831               675.0
# Andorra               0        0        0  ...      918      922                79.0
# Angola                0        0        0  ...     1078     1109                78.0
#
# [5 rows x 192 columns]

# %% [markdown]
# **Creating a new Dataframe with required values**

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['max infection rate'])
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                  915.0
# Albania                      126.0
# Algeria                      675.0
# Andorra                       79.0
# Angola                        78.0

# %% [markdown]
# **Importing World Happiness Report Dataset (By Kaggle)**

# %%
world_happiness_report = pd.read_csv("worldwide_happiness_report.csv")
world_happiness_report.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
columns_to_drop = ['Overall rank','Score','Generosity','Perceptions of corruption']
world_happiness_report.drop(columns_to_drop,axis=1 , inplace=True)
world_happiness_report.head()
# Out:
#   Country or region  ...  Freedom to make life choices
# 0           Finland  ...                         0.596
# 1           Denmark  ...                         0.592
# 2            Norway  ...                         0.603
# 3           Iceland  ...                         0.591
# 4       Netherlands  ...                         0.557
#
# [5 rows x 5 columns]

# %%
world_happiness_report.set_index(['Country or region'],inplace=True)
world_happiness_report.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %% [markdown]
# **Joining Two Data Sets**

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                  915.0
# Albania                      126.0
# Algeria                      675.0
# Andorra                       79.0
# Angola                        78.0

# %%
world_happiness_report.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %%
data = world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#                    GDP per capita  ...  max infection rate
# Country or region                  ...
# Finland                     1.340  ...               267.0
# Denmark                     1.383  ...               391.0
# Norway                      1.488  ...               386.0
# Iceland                     1.380  ...                99.0
# Netherlands                 1.396  ...              1346.0
#
# [5 rows x 5 columns]

# %% [markdown]
# **Correlation**

# %%
data.corr()
# Out:
#                               GDP per capita  ...  max infection rate
# GDP per capita                      1.000000  ...            0.113030
# Social support                      0.754906  ...            0.089777
# Healthy life expectancy             0.835462  ...            0.101342
# Freedom to make life choices        0.379079  ...            0.082580
# max infection rate                  0.113030  ...            1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# **Visualisation of Results**

# %%
data.head()
# Out:
#                    GDP per capita  ...  max infection rate
# Country or region                  ...
# Finland                     1.340  ...               267.0
# Denmark                     1.383  ...               391.0
# Norway                      1.488  ...               386.0
# Iceland                     1.380  ...                99.0
# Netherlands                 1.396  ...              1346.0
#
# [5 rows x 5 columns]

# %%
#GDP vs maximum Infection rate
x = data['GDP per capita']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
#Social support vs maximum Infection rate
x = data['Social support']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
#Healthy life expectancy vs maximum Infection rate
x = data['Healthy life expectancy']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
#Freedom to make life choices vs maximum Infection rate
x = data['Freedom to make life choices']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                  915.0
# Albania                      126.0
# Algeria                      675.0
# Andorra                       79.0
# Angola                        78.0

# %%
corona_data['max infection rate']['India']
# Out:
# 52783.0
